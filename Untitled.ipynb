# %%
import cv2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"E:\BG\lena.jpeg")
print(img)
# Out:
# [[[116 132 221]
#   [116 132 221]
#   [116 132 221]
#   ...
#   [120 132 226]
#   [126 141 233]
#   [100 110 204]]
#
#  [[116 132 221]
#   [116 132 221]
#   [116 132 221]
#   ...
#   [133 141 234]
#   [144 152 242]
#   [112 115 206]]
#
#  [[116 132 221]
#   [116 132 221]
#   [115 130 222]
#   ...
#   [107 108 198]
#   [108 104 193]
#   [ 72  58 146]]
#
#  ...
#
#  [[ 65  21  92]
#   [ 62  20  91]
#   [ 59  19  90]
#   ...
#   [ 71  38 122]
#   [ 79  52 138]
#   [ 75  57 151]]
#
#  [[ 62  18  87]
#   [ 57  16  84]
#   [ 56  14  85]
#   ...
#   [ 74  45 131]
#   [ 86  61 153]
#   [ 75  62 160]]
#
#  [[ 53  14  76]
#   [ 84  44 109]
#   [ 61  20  88]
#   ...
#   [ 86  62 157]
#   [ 87  66 168]
#   [ 81  69 175]]]

# %%
cv2.imshow("My image",img)
