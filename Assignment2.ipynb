# %%
'''2. Implement point processing a) Image negative b) Power law transform c) log transform '''
# Out:
# '2. Implement point processing a) Image negative b) Power law transform c) log transform '

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('E:\BG\pic\misc\jenna.TIFF',0)

negative = 255-image

gamma = 0.5
power_law = np.power(image / 255.0, gamma) * 255.0
power_law = power_law.astype(np.uint8)

c = 255 / np.log(1 + np.max(image))
log_transform = c * np.log(1 + image)
log_transform = log_transform.astype(np.uint8)

plt.figure(figsize=(12, 4))
plt.subplot(1, 4, 1)
plt.imshow(image, cmap='gray')
plt.title('Original')
plt.subplot(1, 4, 2)
plt.imshow(negative, cmap='gray')
plt.title('Negative')
plt.subplot(1, 4, 3)
plt.imshow(power_law, cmap='gray')
plt.title('Power Law')
plt.subplot(1, 4, 4)
plt.imshow(log_transform, cmap='gray')
plt.title('Log Transform')
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\ASMIT HALDER\AppData\Local\Temp\ipykernel_36332\900654549.py:1: SyntaxWarning: invalid escape sequence '\B'
#   image = cv2.imread('E:\BG\pic\misc\jenna.TIFF',0)
# C:\Users\ASMIT HALDER\AppData\Local\Temp\ipykernel_36332\900654549.py:9: RuntimeWarning: overflow encountered in scalar add
#   c = 255 / np.log(1 + np.max(image))
# C:\Users\ASMIT HALDER\AppData\Local\Temp\ipykernel_36332\900654549.py:9: RuntimeWarning: divide by zero encountered in log
#   c = 255 / np.log(1 + np.max(image))
# C:\Users\ASMIT HALDER\AppData\Local\Temp\ipykernel_36332\900654549.py:10: RuntimeWarning: divide by zero encountered in log
#   log_transform = c * np.log(1 + image)
# C:\Users\ASMIT HALDER\AppData\Local\Temp\ipykernel_36332\900654549.py:10: RuntimeWarning: invalid value encountered in multiply
#   log_transform = c * np.log(1 + image)
# ...
