# %%
from IPython.display import display,HTML
display(HTML("<h1>CROP OPERATION<h1>"))
# Out:
# <h1>CROP OPERATION<h1>

# %%
import cv2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
img=cv2.imread("E:/BG/pic/ww2.tif",0)

# %%
xc,yc=img.shape[0]//2,img.shape[1]//2

# %%
d=300

# %%
cimg=img.copy()

# %%
cimg[xc-d//2:xc+d//2,yc-d//2:yc+d//2]=0

# %%
plt.imshow(cimg,cmap='gray')
plt.show()
